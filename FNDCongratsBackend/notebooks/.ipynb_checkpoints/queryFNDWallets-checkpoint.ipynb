# %%
from gql import Client, gql
from gql.transport.aiohttp import AIOHTTPTransport
import time
from datetime import datetime

# %%
def get_current_unix():
    return int(time.time())

# %%
fnd_url = 'https://api.thegraph.com/subgraphs/name/f8n/fnd'

# Select your transport with a defined url endpoint
transport = AIOHTTPTransport(url=fnd_url)

# Create a GraphQL client using the defined transport
client = Client(transport=transport, fetch_schema_from_transport=True)

# %%
# https://www.graphqlbin.com/v2/new

# %%
# start_time = "1657065600"
# end_time = "1657069200"
end_time = get_current_unix()
start_time = 0#end_time - 3600
# Provide a GraphQL query
query = gql(
    """
    query test($start:BigInt, $end:BigInt, $id_in: [ID!]){
        creators(where: {id_in: $id_in }) {
            id
            nfts (orderBy: dateMinted) {
            nftContract {
                id
                name
                symbol
            }
            tokenId
            tokenIPFSPath
            dateMinted
            isFirstSale
            nftHistory (orderBy: date, where: {
                event_in: [Bid, BuyPriceAccepted], date_gt: $start, date_lte: $end
            }) {
                actorAccount {
                id
                }
                event
                date
                amountInETH
            }
            lastSalePriceInETH
            }
        }
    }
"""
)

# %%
addresses = ["0xa3ffe0852407580a043e704d1767adfc6d7acc41", "0xa6616f91d6a6d554213ca3f11f87dc525ea82803", "0xa5ed4cb9f460e89303ff1bf8b11b20987a4a2f72", "0x18cafd72a2b1efa67c9dafa77aa874618b27e38e", "0x2da88c8a45f32f2f84d7c675512ab045b3673cf9", "0x60b6f16f8b52c2966420fb4a7f9d1b7fdb999518", "0xae6523e811edc6d16b806875fbf2082e01fb3117", "0x65a7e0554eba32df644805bf6bd463f6e7a37a77", "0xc9bb2cd8c473f012bc839fcab644ec9d9f8f4557", "0x28aa1bda95bd43e502bf96fa8fd560edc9bc3ac2", "0x612b194218cedbe38a418b79106e12dedd75e0cc", "0x752f004b6e8cb9ed62be55c964257d1955478ea1", "0x71feea315e5026c09db3e260cdaec14c3d990b75", "0x9fef6f79977d2fbc78227d914222e78bfa95c30c", "0xd3a846303e52d6b7f7e2605103cc1af1f503a949", "0x4b416807473bd926ef0f3ee77d383e908e39dc3a", "0x3f6e2f3380ad5b3187c513832d14b9517d87639e", "0x52fcde35b1bd070eecb2c60a730af8816e420b53", "0xfb7d7c678c6bfc03952d9c9c7427d3fb8d3142f9", "0xe23d6582b37818f0fdeb4dcdbb8e63e6b7dacb84", "0xa6c2bbc6d9b2039965efce4d4fcafb47c4069e6a", "0x4c5c59b023e8b1b3c5633bfb4c9e7cc2f796579d", "0x471100bd609ac6bdb33a7e5d636d07057b77111a", "0xafe82d46210ec8d2b580fde4ed088a4b73083d7e", "0xf88a9e0d5bd66984628aee7944858ed992dda586", "0xd2f223de67d69e0c576a3a5f8a300cb02e79941d", "0x64e44f61615e6662cd70f1e57ca57b08c6660591", "0xfde8604980e8db7d965c86028bbbf136b7836606", "0xd4849bec09de2ab271ef92df0b6e7faaabf07adf", "0x14a02abba072c026dfef8f7f5582fc3ff18bcad7"]
addresses = addresses[:-20]
addresses.append("0xF46E179D808eBdFAED29Cd511326aEe00049BCFa".lower()) # note all must be lower case :/, update the code in nodejs
print(addresses)
params = {
    "start": start_time,
    "end": end_time,
    "id_in": addresses
}
result = await client.execute_async(query, variable_values=params)
# Out:
# ['0xa3ffe0852407580a043e704d1767adfc6d7acc41', '0xa6616f91d6a6d554213ca3f11f87dc525ea82803', '0xa5ed4cb9f460e89303ff1bf8b11b20987a4a2f72', '0x18cafd72a2b1efa67c9dafa77aa874618b27e38e', '0x2da88c8a45f32f2f84d7c675512ab045b3673cf9', '0x60b6f16f8b52c2966420fb4a7f9d1b7fdb999518', '0xae6523e811edc6d16b806875fbf2082e01fb3117', '0x65a7e0554eba32df644805bf6bd463f6e7a37a77', '0xc9bb2cd8c473f012bc839fcab644ec9d9f8f4557', '0x28aa1bda95bd43e502bf96fa8fd560edc9bc3ac2', '0xf46e179d808ebdfaed29cd511326aee00049bcfa']

# %%
result = client.execute(query, variable_values=params)

# %%
# Cron job every 6 hours, update list of wallet addrs in a json
# Cron job every 1 hour to pull for data

# %%
print(len(addresses))
# Out:
# 11

# %%
print(result)
# Out:
# {'creators': [{'id': '0x18cafd72a2b1efa67c9dafa77aa874618b27e38e', 'nfts': [{'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '1', 'tokenIPFSPath': 'QmcoMMm4J9QV5XEDL8Qkhb5YR6oVL2na8pVGFsUgSaS3n6/metadata.json', 'dateMinted': '1644035921', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xed9ef31030f0316da7c9c92bf35ac71e1669389f'}, 'event': 'Bid', 'date': '1644037055', 'amountInETH': '0.369'}, {'actorAccount': {'id': '0xc569ddad0ba0f22fce53b0422a0f80acc9f8b1d3'}, 'event': 'Bid', 'date': '1644038788', 'amountInETH': '0.41'}, {'actorAccount': {'id': '0xed9ef31030f0316da7c9c92bf35ac71e1669389f'}, 'event': 'Bid', 'date': '1644121178', 'amountInETH': '0.4569'}], 'lastSalePriceInETH': '0.4569'}, {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '2', 'tokenIPFSPath': 'QmaUsuEd25G7P2oeFGL1RNf73NSyRzhrJMVxsj5yCKzwBL/metadata.json', 'dateMinted': '1644597678', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xbd74c3f96c38478460a0e3c88ac86dd133af72be'}, 'event': 'Bid', 'date': '1644636349', 'amountInETH': '0.15'}, {'actorAccount': {'id': '0xc395b609bb4690dee3453c2cd338f4e8ed6aae4a'}, 'event': 'Bid', 'date': '1644636642', 'amountInETH': '0.2'}, {'actorAccount': {'id': '0xed9ef31030f0316da7c9c92bf35ac71e1669389f'}, 'event': 'Bid', 'date': '1644638625', 'amountInETH': '0.2269'}, {'actorAccount': {'id': '0xd1ef10cc1b9588f75a980f743c2677eb04b7ce18'}, 'event': 'Bid', 'date': '1644639819', 'amountInETH': '0.2496'}], 'lastSalePriceInETH': '0.2496'}, {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '3', 'tokenIPFSPath': 'QmYD8qKNLZJfF5RUvyqk9LvhEi4DQeYNpXYZ44RaFW6HEJ/metadata.json', 'dateMinted': '1645190834', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xc395b609bb4690dee3453c2cd338f4e8ed6aae4a'}, 'event': 'Bid', 'date': '1645247161', 'amountInETH': '0.2'}, {'actorAccount': {'id': '0xae39c99270a91fa2cd76f76abc176a873706062f'}, 'event': 'Bid', 'date': '1645247345', 'amountInETH': '0.269'}, {'actorAccount': {'id': '0x5445fceeb247a18a6198ab65c6329e8c70f6d4e7'}, 'event': 'Bid', 'date': '1645331120', 'amountInETH': '0.296'}], 'lastSalePriceInETH': '0.296'}, {'nftContract': {'id': '0x02cc315cec28d7ba6d6ec8ffefdff07140c71b21', 'name': "Tanaka's Cat Girls Collection", 'symbol': 'TANACAT'}, 'tokenId': '1', 'tokenIPFSPath': 'QmTn9kwMctY2vrrBfrCoxuMTbKBPQnMMsG7heDQBi7bBhL/metadata.json', 'dateMinted': '1645458001', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x3028d697fc398b8016e961337b37eba2af562354'}, 'event': 'Bid', 'date': '1645530918', 'amountInETH': '0.15'}, {'actorAccount': {'id': '0x79ec854e8c5a6d04dbbb340cef8209fe08b0c7b1'}, 'event': 'Bid', 'date': '1645531509', 'amountInETH': '0.165'}, {'actorAccount': {'id': '0x938a0af4b86057489bc651dd02c080890d8ed5e5'}, 'event': 'Bid', 'date': '1645608081', 'amountInETH': '0.1869'}], 'lastSalePriceInETH': '0.1869'}, {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '4', 'tokenIPFSPath': 'QmcVV1H8k5jGS2n5wwDELvmKuKZA6VvyvVvgygiuVfeHLe/metadata.json', 'dateMinted': '1646058305', 'isFirstSale': True, 'nftHistory': [], 'lastSalePriceInETH': None}, {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '5', 'tokenIPFSPath': 'QmQTPUsWNiDmfwXB51shZGR6kKwAVxns8o7EEtLogBwdgU/metadata.json', 'dateMinted': '1646061867', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x38abe3934630a84dd024146f1a20addaa4ecb9a9'}, 'event': 'Bid', 'date': '1646131123', 'amountInETH': '0.2'}, {'actorAccount': {'id': '0xc395b609bb4690dee3453c2cd338f4e8ed6aae4a'}, 'event': 'Bid', 'date': '1646138531', 'amountInETH': '0.2201'}, {'actorAccount': {'id': '0xed9ef31030f0316d ...

# %%
msgs = []
for c in result['creators']:
    print(f"id: {c['id']}")
    addr = c['id']
    for nft in c['nfts']:
#         print(f"isFirstSale? {nft['isFirstSale']}")
        if(len(nft['nftHistory']) > 0):
            print(nft)
            msgs.append(messageCreator(addr,nft))
# Out:
# id: 0x18cafd72a2b1efa67c9dafa77aa874618b27e38e
# {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '1', 'tokenIPFSPath': 'QmcoMMm4J9QV5XEDL8Qkhb5YR6oVL2na8pVGFsUgSaS3n6/metadata.json', 'dateMinted': '1644035921', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xed9ef31030f0316da7c9c92bf35ac71e1669389f'}, 'event': 'Bid', 'date': '1644037055', 'amountInETH': '0.369'}, {'actorAccount': {'id': '0xc569ddad0ba0f22fce53b0422a0f80acc9f8b1d3'}, 'event': 'Bid', 'date': '1644038788', 'amountInETH': '0.41'}, {'actorAccount': {'id': '0xed9ef31030f0316da7c9c92bf35ac71e1669389f'}, 'event': 'Bid', 'date': '1644121178', 'amountInETH': '0.4569'}], 'lastSalePriceInETH': '0.4569'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.369 ETH
# Event Date: 2022-02-05 04:57:35 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.41 ETH
# Event Date: 2022-02-05 05:26:28 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.4569 ETH
# Event Date: 2022-02-06 04:19:38 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/1
# {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '2', 'tokenIPFSPath': 'QmaUsuEd25G7P2oeFGL1RNf73NSyRzhrJMVxsj5yCKzwBL/metadata.json', 'dateMinted': '1644597678', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xbd74c3f96c38478460a0e3c88ac86dd133af72be'}, 'event': 'Bid', 'date': '1644636349', 'amountInETH': '0.15'}, {'actorAccount': {'id': '0xc395b609bb4690dee3453c2cd338f4e8ed6aae4a'}, 'event': 'Bid', 'date': '1644636642', 'amountInETH': '0.2'}, {'actorAccount': {'id': '0xed9ef31030f0316da7c9c92bf35ac71e1669389f'}, 'event': 'Bid', 'date': '1644638625', 'amountInETH': '0.2269'}, {'actorAccount': {'id': '0xd1ef10cc1b9588f75a980f743c2677eb04b7ce18'}, 'event': 'Bid', 'date': '1644639819', 'amountInETH': '0.2496'}], 'lastSalePriceInETH': '0.2496'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2022-02-12 03:25:49 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/2
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2022-02-12 03:30:42 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/2
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2269 ETH
# Event Date: 2022-02-12 04:03:45 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/2
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2496 ETH
# Event Date: 2022-02-12 04:23:39 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/2
# {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '3', 'tokenIPFSPath': 'QmYD8qKNLZJfF5RUvyqk9LvhEi4DQeYNpXYZ44RaFW6HEJ/metadata.json', 'dateMinted': '1645190834', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xc395b609bb4690dee3453c2cd338f4e8ed6aae4a'}, 'event': 'Bid', 'date': '1645247161', 'amountInETH': '0.2'}, {'actorAccount': {'id': '0xae39c99270a91fa2cd76f76abc176a873706062f'}, 'event': 'Bid', 'date': '1645247345', 'amountInETH': '0.269'}, {'actorAccount': {'id': '0x5445fceeb247a18a6198ab65c6329e8c70f6d4e7'}, 'event': 'Bid', 'date': '1645331120', 'amountInETH': '0.296'}], 'lastSalePriceInETH': '0.296'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2022-02-19 05:06:01 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.269 ETH
# Event Date: 2022-02-19 05:09:05 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.296 ETH
# Event Date: 2022-02-20 04:25:20 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/3
# {'nftContract': {'id': '0x02cc315cec28d7ba6d6ec8ffefdff07140c71b21', 'name': "Tanaka's Cat Girls Collection", 'symbol': 'TANACAT'}, 'tokenId': '1', 'tokenIPFSPath': 'QmTn9kwMctY2vrrBfrCoxuMTbKBPQnMMsG7heDQBi7bBhL/metadata.json', 'dateMinted': '1645458001', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x3028d697fc398b8016e961337b37eba2af562354'}, 'event': 'Bid', 'date': '1645530918', 'amountInETH': '0.15'}, {'actorAccount': {'id': '0x79ec854e8c5a6d04dbbb340cef8209fe08b0c7b1'}, 'event': 'Bid', 'date': '1645531509', 'amountInETH': '0.165'}, {'actorAccount': {'id': '0x938a0af4b86057489bc651dd02c080890d8ed5e5'}, 'event': 'Bid', 'date': '1645608081', 'amountInETH': '0.1869'}], 'lastSalePriceInETH': '0.1869'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2022-02-22 11:55:18 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.165 ETH
# Event Date: 2022-02-22 12:05:09 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1869 ETH
# Event Date: 2022-02-23 09:21:21 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/1
# {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '5', 'tokenIPFSPath': 'QmQTPUsWNiDmfwXB51shZGR6kKwAVxns8o7EEtLogBwdgU/metadata.json', 'dateMinted': '1646061867', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x38abe3934630a84dd024146f1a20addaa4ecb9a9'}, 'event': 'Bid', 'date': '1646131123', 'amountInETH': '0.2'}, {'actorAccount': {'id': '0xc395b609bb4690dee3453c2cd338f4e8ed6aae4a'}, 'event': 'Bid', 'date': '1646138531', 'amountInETH': '0.2201'}, {'actorAccount': {'id': '0xed9ef31030f0316da7c9c92bf35ac71e1669389f'}, 'event': 'Bid', 'date': '1646194919', 'amountInETH': '0.2469'}], 'lastSalePriceInETH': '0.2469'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2022-03-01 10:38:43 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/5
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2201 ETH
# Event Date: 2022-03-01 12:42:11 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/5
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2469 ETH
# Event Date: 2022-03-02 04:21:59 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/5
# {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '6', 'tokenIPFSPath': 'QmWTPFxpvLGHkRAidbhPFjH4XrgB3JKVVuW8HCnku8LHDb/metadata.json', 'dateMinted': '1648720538', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xb3cbaf94c1ce3aa95ccf71d43afc92159f521b04'}, 'event': 'Bid', 'date': '1648897286', 'amountInETH': '0.1'}, {'actorAccount': {'id': '0xc569ddad0ba0f22fce53b0422a0f80acc9f8b1d3'}, 'event': 'Bid', 'date': '1648899093', 'amountInETH': '0.169'}, {'actorAccount': {'id': '0x1fb576ce36f72b056b456554622335e9dccd6f3f'}, 'event': 'Bid', 'date': '1648901330', 'amountInETH': '0.189'}, {'actorAccount': {'id': '0x65375f91a2159e472a9f3df8884dd94c5d697703'}, 'event': 'Bid', 'date': '1648905189', 'amountInETH': '0.2079'}, {'actorAccount': {'id': '0xed9ef31030f0316da7c9c92bf35ac71e1669389f'}, 'event': 'Bid', 'date': '1648952264', 'amountInETH': '0.2296'}], 'lastSalePriceInETH': '0.2296'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1 ETH
# Event Date: 2022-04-02 11:01:26 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/6
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.169 ETH
# Event Date: 2022-04-02 11:31:33 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/6
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.189 ETH
# Event Date: 2022-04-02 12:08:50 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/6
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2079 ETH
# Event Date: 2022-04-02 13:13:09 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/6
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2296 ETH
# Event Date: 2022-04-03 02:17:44 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/6
# {'nftContract': {'id': '0x02cc315cec28d7ba6d6ec8ffefdff07140c71b21', 'name': "Tanaka's Cat Girls Collection", 'symbol': 'TANACAT'}, 'tokenId': '3', 'tokenIPFSPath': 'QmajVxJNcyKKFGiVDjAhbEFiVzGV3izNpjzLxoU3173zni/metadata.json', 'dateMinted': '1649402774', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xd7af5ea14fad145b2d9fd57e321d7bf8301980b5'}, 'event': 'Bid', 'date': '1649501235', 'amountInETH': '0.11'}, {'actorAccount': {'id': '0xed9ef31030f0316da7c9c92bf35ac71e1669389f'}, 'event': 'Bid', 'date': '1649502348', 'amountInETH': '0.1269'}, {'actorAccount': {'id': '0x7021163e97179b328dc746ca9213174ca180df04'}, 'event': 'Bid', 'date': '1649506725', 'amountInETH': '0.1396'}, {'actorAccount': {'id': '0x79336089d91cd17a875adf63c66def70f5eb7e8c'}, 'event': 'Bid', 'date': '1649545722', 'amountInETH': '0.154'}], 'lastSalePriceInETH': '0.154'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.11 ETH
# Event Date: 2022-04-09 10:47:15 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1269 ETH
# Event Date: 2022-04-09 11:05:48 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1396 ETH
# Event Date: 2022-04-09 12:18:45 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.154 ETH
# Event Date: 2022-04-09 23:08:42 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/3
# {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '7', 'tokenIPFSPath': 'QmRAtnxeD8PXjNmAeX9gqJFwSK6gBtWjbHatf9WHYV7UYb/metadata.json', 'dateMinted': '1650526907', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xc569ddad0ba0f22fce53b0422a0f80acc9f8b1d3'}, 'event': 'Bid', 'date': '1650624781', 'amountInETH': '0.169'}, {'actorAccount': {'id': '0x228409dc6f08fa3071e1fdd8491bf69da42e79f2'}, 'event': 'Bid', 'date': '1650630707', 'amountInETH': '0.1859'}, {'actorAccount': {'id': '0x42de10a720c59ed8dcc6e55d5e61e03b5ad70905'}, 'event': 'Bid', 'date': '1650699568', 'amountInETH': '0.24'}], 'lastSalePriceInETH': '0.24'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.169 ETH
# Event Date: 2022-04-22 10:53:01 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/7
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1859 ETH
# Event Date: 2022-04-22 12:31:47 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/7
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.24 ETH
# Event Date: 2022-04-23 07:39:28 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/7
# {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '8', 'tokenIPFSPath': 'QmYu3nnynXCyiiwpy9W6MnDJpHazbLRZ6YPy699CETwSLA/metadata.json', 'dateMinted': '1651231395', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xfba1291ad0615734503dacf8f16eecdd4e79d8ef'}, 'event': 'Bid', 'date': '1651415055', 'amountInETH': '0.15'}, {'actorAccount': {'id': '0x92e9b91aa2171694d740e7066f787739ca1af9de'}, 'event': 'Bid', 'date': '1651419158', 'amountInETH': '0.169'}, {'actorAccount': {'id': '0xfba1291ad0615734503dacf8f16eecdd4e79d8ef'}, 'event': 'Bid', 'date': '1651427760', 'amountInETH': '0.199'}], 'lastSalePriceInETH': '0.199'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2022-05-01 14:24:15 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/8
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.169 ETH
# Event Date: 2022-05-01 15:32:38 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/8
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.199 ETH
# Event Date: 2022-05-01 17:56:00 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/8
# {'nftContract': {'id': '0x02cc315cec28d7ba6d6ec8ffefdff07140c71b21', 'name': "Tanaka's Cat Girls Collection", 'symbol': 'TANACAT'}, 'tokenId': '5', 'tokenIPFSPath': 'QmQwFLF64GbNG4egLnbDSrs2isYQQT93RFvyoWcZiu1MTU/metadata.json', 'dateMinted': '1652283872', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x2e65ecfd229f2071ea40dbe20449be91fad50894'}, 'event': 'Bid', 'date': '1654875602', 'amountInETH': '0.15'}, {'actorAccount': {'id': '0x8c68a303d725afef6deeaeea04f37aef808efc1b'}, 'event': 'Bid', 'date': '1654961856', 'amountInETH': '0.165'}], 'lastSalePriceInETH': '0.165'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2022-06-10 15:40:02 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/5
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.165 ETH
# Event Date: 2022-06-11 15:37:36 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/5
# {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '9', 'tokenIPFSPath': 'Qmb5ADesWdMoCrx18DCvdVya9ufjKbndfKGYC2R7CnizXx/metadata.json', 'dateMinted': '1653400720', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xc569ddad0ba0f22fce53b0422a0f80acc9f8b1d3'}, 'event': 'Bid', 'date': '1653430671', 'amountInETH': '0.2'}, {'actorAccount': {'id': '0xf569e5fea87cb45da33ab8246080c73c50ccd950'}, 'event': 'Bid', 'date': '1653431158', 'amountInETH': '0.25'}, {'actorAccount': {'id': '0x42de10a720c59ed8dcc6e55d5e61e03b5ad70905'}, 'event': 'Bid', 'date': '1653431177', 'amountInETH': '0.33'}, {'actorAccount': {'id': '0xb293ce478862e49ed0ada2c755c8abcd43cc1e4c'}, 'event': 'Bid', 'date': '1653432690', 'amountInETH': '0.365'}, {'actorAccount': {'id': '0x07f97a064267feabd1874612cb684728bf7c9f7f'}, 'event': 'Bid', 'date': '1653443405', 'amountInETH': '0.402'}], 'lastSalePriceInETH': '0.402'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2022-05-24 22:17:51 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/9
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.25 ETH
# Event Date: 2022-05-24 22:25:58 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/9
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.33 ETH
# Event Date: 2022-05-24 22:26:17 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/9
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.365 ETH
# Event Date: 2022-05-24 22:51:30 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/9
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.402 ETH
# Event Date: 2022-05-25 01:50:05 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/9
# {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '10', 'tokenIPFSPath': 'QmS3dde59RiWNz7yhXvcGbLMEFhDWAuZoi8RtF58iFbgur/metadata.json', 'dateMinted': '1653984652', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xc569ddad0ba0f22fce53b0422a0f80acc9f8b1d3'}, 'event': 'Bid', 'date': '1654080823', 'amountInETH': '0.2'}, {'actorAccount': {'id': '0x42de10a720c59ed8dcc6e55d5e61e03b5ad70905'}, 'event': 'Bid', 'date': '1654153082', 'amountInETH': '0.32'}], 'lastSalePriceInETH': '0.32'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2022-06-01 10:53:43 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/10
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.32 ETH
# Event Date: 2022-06-02 06:58:02 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/10
# {'nftContract': {'id': '0x02cc315cec28d7ba6d6ec8ffefdff07140c71b21', 'name': "Tanaka's Cat Girls Collection", 'symbol': 'TANACAT'}, 'tokenId': '6', 'tokenIPFSPath': 'QmeiVHRE6xb1QhG89rE4KvgtF7u6TWL4368jdv25wzrLGA/metadata.json', 'dateMinted': '1655364047', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x18cafd72a2b1efa67c9dafa77aa874618b27e38e'}, 'event': 'BuyPriceAccepted', 'date': '1655378653', 'amountInETH': '0.3'}], 'lastSalePriceInETH': '0.3'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.3 ETH
# Event Date: 2022-06-16 11:24:13 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/6
# {'nftContract': {'id': '0x02cc315cec28d7ba6d6ec8ffefdff07140c71b21', 'name': "Tanaka's Cat Girls Collection", 'symbol': 'TANACAT'}, 'tokenId': '7', 'tokenIPFSPath': 'QmTFx2eAxNUGatxyKqC9atnaMFonVx4k1BGHmrdDZ8n3SF/metadata.json', 'dateMinted': '1655640616', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x36f4e1803f6ff34562db567f347dea00dec87246'}, 'event': 'Bid', 'date': '1655657848', 'amountInETH': '0.15'}, {'actorAccount': {'id': '0xb618aacb9dcdc21ca69d310a6fc04674d293a193'}, 'event': 'Bid', 'date': '1655679663', 'amountInETH': '0.169'}, {'actorAccount': {'id': '0x8c68a303d725afef6deeaeea04f37aef808efc1b'}, 'event': 'Bid', 'date': '1655724703', 'amountInETH': '0.1859'}, {'actorAccount': {'id': '0xb618aacb9dcdc21ca69d310a6fc04674d293a193'}, 'event': 'Bid', 'date': '1655736315', 'amountInETH': '0.2069'}], 'lastSalePriceInETH': '0.2069'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2022-06-19 16:57:28 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/7
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.169 ETH
# Event Date: 2022-06-19 23:01:03 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/7
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1859 ETH
# Event Date: 2022-06-20 11:31:43 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/7
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2069 ETH
# Event Date: 2022-06-20 14:45:15 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/7
# {'nftContract': {'id': '0x5e6bcb6c6585cba5c4ec81cb5d77475aca9b349a', 'name': 'The Moment Of Someday', 'symbol': 'TMOS'}, 'tokenId': '12', 'tokenIPFSPath': 'Qmc2Xp1jnRGVujpiC9YU4MfFNvFxvPQqdqEe8wXAVJqzvT/metadata.json', 'dateMinted': '1656288825', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xd0fe971732e547059ea6009c79a2d6155bdb41a4'}, 'event': 'Bid', 'date': '1656293775', 'amountInETH': '0.123'}, {'actorAccount': {'id': '0xb18e3a7152060941ef92c2ad5872d76fc4091059'}, 'event': 'Bid', 'date': '1656331950', 'amountInETH': '0.1355'}], 'lastSalePriceInETH': '0.1355'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.123 ETH
# Event Date: 2022-06-27 01:36:15 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/12
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1355 ETH
# Event Date: 2022-06-27 12:12:30 UTC
# FND Link: https://foundation.app/@Okanyan/TMOS/12
# {'nftContract': {'id': '0x02cc315cec28d7ba6d6ec8ffefdff07140c71b21', 'name': "Tanaka's Cat Girls Collection", 'symbol': 'TANACAT'}, 'tokenId': '8', 'tokenIPFSPath': 'QmRYB6HScWnS8DPnJ3WKUMsow2DKYCGQcKDRxcpTCyQiZa/metadata.json', 'dateMinted': '1657086605', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xf2ef8aa28ea7e38043d71d6e1aa011030bc31c5c'}, 'event': 'Bid', 'date': '1657097818', 'amountInETH': '0.15'}, {'actorAccount': {'id': '0xb293ce478862e49ed0ada2c755c8abcd43cc1e4c'}, 'event': 'Bid', 'date': '1657140464', 'amountInETH': '0.165'}, {'actorAccount': {'id': '0x880c4f74c3d4c39d75f8e2ad958f40671416bf66'}, 'event': 'Bid', 'date': '1657174155', 'amountInETH': '0.369'}], 'lastSalePriceInETH': '0.369'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2022-07-06 08:56:58 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/8
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.165 ETH
# Event Date: 2022-07-06 20:47:44 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/8
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.369 ETH
# Event Date: 2022-07-07 06:09:15 UTC
# FND Link: https://foundation.app/@Okanyan/TANACAT/8
# id: 0x28aa1bda95bd43e502bf96fa8fd560edc9bc3ac2
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '78278', 'tokenIPFSPath': 'QmUo1zUc1dtQhLWUnPCpK5BrYUQ4axrBLfYVctSr97APTX/metadata.json', 'dateMinted': '1630211832', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xc976e16c389bab9c3902aaec797a0989c395c9b5'}, 'event': 'Bid', 'date': '1630827408', 'amountInETH': '0.1'}, {'actorAccount': {'id': '0xc9d19a28b43c36b2498233d9cd0998a6ee3b4c54'}, 'event': 'Bid', 'date': '1630911125', 'amountInETH': '0.2'}, {'actorAccount': {'id': '0xb79157bca1635f4731df5828f2a28a0cbfc799ce'}, 'event': 'Bid', 'date': '1630913480', 'amountInETH': '0.25'}, {'actorAccount': {'id': '0xc9d19a28b43c36b2498233d9cd0998a6ee3b4c54'}, 'event': 'Bid', 'date': '1630913619', 'amountInETH': '0.3'}, {'actorAccount': {'id': '0xb79157bca1635f4731df5828f2a28a0cbfc799ce'}, 'event': 'Bid', 'date': '1630913774', 'amountInETH': '0.35'}], 'lastSalePriceInETH': '0.35'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1 ETH
# Event Date: 2021-09-05 07:36:48 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/78278
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2021-09-06 06:52:05 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/78278
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.25 ETH
# Event Date: 2021-09-06 07:31:20 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/78278
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.3 ETH
# Event Date: 2021-09-06 07:33:39 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/78278
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.35 ETH
# Event Date: 2021-09-06 07:36:14 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/78278
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '83393', 'tokenIPFSPath': 'QmV3y1u5iKQepSHazTHtXKyhGFhD7aX32mshMFADN7jjKB/metadata.json', 'dateMinted': '1631317985', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xa3917c68d49dfe0323321b4a7f2ec88074647dd0'}, 'event': 'Bid', 'date': '1633742066', 'amountInETH': '0.15'}], 'lastSalePriceInETH': '0.15'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2021-10-09 01:14:26 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/83393
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '88332', 'tokenIPFSPath': 'QmP3FBou8bnaZMMPtnv7FXt2adkEidhjtQHBaCXJNm2Nya/metadata.json', 'dateMinted': '1632098337', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x71df51930da12a7b86b25462f482ce906530d9a6'}, 'event': 'Bid', 'date': '1633190420', 'amountInETH': '0.15'}], 'lastSalePriceInETH': '0.15'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2021-10-02 16:00:20 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/88332
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '96147', 'tokenIPFSPath': 'Qmc25nwQSosv4psNjwMPr9H3StDYh16VCfCdWczASBnMS8/metadata.json', 'dateMinted': '1633833803', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x0303d829d9b81d0939a974cb0c88ea27ab7129c9'}, 'event': 'Bid', 'date': '1633835554', 'amountInETH': '0.2'}], 'lastSalePriceInETH': '0.2'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2021-10-10 03:12:34 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/96147
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '102396', 'tokenIPFSPath': 'QmYYaoK6wHREmyv181MMKsp7CqdACCyknevWuk7iqUsDrz/metadata.json', 'dateMinted': '1635066923', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x1d249860acf2c1bde1f2a8642200edc719969230'}, 'event': 'Bid', 'date': '1635607829', 'amountInETH': '0.5'}], 'lastSalePriceInETH': '0.5'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2021-10-30 15:30:29 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/102396
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '104836', 'tokenIPFSPath': 'QmQXYcSjznWo3ysi54yA6e5qmdQLrc3jojJAJopnxh4pYi/metadata.json', 'dateMinted': '1636092731', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x355b5a3dd1ad1cd298e3f160da1d43f2c5c33ad7'}, 'event': 'Bid', 'date': '1636610204', 'amountInETH': '0.58'}, {'actorAccount': {'id': '0xf305f90b19cf66fc2d038f92a26440b66cf858f6'}, 'event': 'Bid', 'date': '1636682978', 'amountInETH': '0.638'}, {'actorAccount': {'id': '0x355b5a3dd1ad1cd298e3f160da1d43f2c5c33ad7'}, 'event': 'Bid', 'date': '1636694623', 'amountInETH': '0.7019'}, {'actorAccount': {'id': '0xf305f90b19cf66fc2d038f92a26440b66cf858f6'}, 'event': 'Bid', 'date': '1636694901', 'amountInETH': '0.7721'}, {'actorAccount': {'id': '0x355b5a3dd1ad1cd298e3f160da1d43f2c5c33ad7'}, 'event': 'Bid', 'date': '1636695804', 'amountInETH': '0.8494'}, {'actorAccount': {'id': '0xf305f90b19cf66fc2d038f92a26440b66cf858f6'}, 'event': 'Bid', 'date': '1636696000', 'amountInETH': '0.9344'}, {'actorAccount': {'id': '0x355b5a3dd1ad1cd298e3f160da1d43f2c5c33ad7'}, 'event': 'Bid', 'date': '1636696601', 'amountInETH': '1.0279'}, {'actorAccount': {'id': '0xf305f90b19cf66fc2d038f92a26440b66cf858f6'}, 'event': 'Bid', 'date': '1636696745', 'amountInETH': '1.28'}], 'lastSalePriceInETH': '1.28'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.58 ETH
# Event Date: 2021-11-11 05:56:44 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/104836
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.638 ETH
# Event Date: 2021-11-12 02:09:38 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/104836
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.7019 ETH
# Event Date: 2021-11-12 05:23:43 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/104836
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.7721 ETH
# Event Date: 2021-11-12 05:28:21 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/104836
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.8494 ETH
# Event Date: 2021-11-12 05:43:24 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/104836
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.9344 ETH
# Event Date: 2021-11-12 05:46:40 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/104836
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 1.0279 ETH
# Event Date: 2021-11-12 05:56:41 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/104836
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 1.28 ETH
# Event Date: 2021-11-12 05:59:05 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/104836
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '109853', 'tokenIPFSPath': 'QmXryATo6XhvC7YnN2rTU8QFKAMCbedhPp2bpuzk3QmBJf/metadata.json', 'dateMinted': '1637480586', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x355b5a3dd1ad1cd298e3f160da1d43f2c5c33ad7'}, 'event': 'Bid', 'date': '1639208461', 'amountInETH': '0.52'}], 'lastSalePriceInETH': '0.52'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.52 ETH
# Event Date: 2021-12-11 07:41:01 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/109853
# {'nftContract': {'id': '0x79a6da61d54725e97f968437f2090948e5e0fa25', 'name': 'Noir et Blanc collection', 'symbol': 'NEBC'}, 'tokenId': '1', 'tokenIPFSPath': 'QmXSsSgpCSEH4FaTjP47Q4bwkLaiTBjLFq3qdRLuwinNMa/metadata.json', 'dateMinted': '1639907666', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x2e65ecfd229f2071ea40dbe20449be91fad50894'}, 'event': 'Bid', 'date': '1640119115', 'amountInETH': '0.5'}], 'lastSalePriceInETH': '0.5'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2021-12-21 20:38:35 UTC
# FND Link: https://foundation.app/@Okanyan/NEBC/1
# {'nftContract': {'id': '0x79a6da61d54725e97f968437f2090948e5e0fa25', 'name': 'Noir et Blanc collection', 'symbol': 'NEBC'}, 'tokenId': '2', 'tokenIPFSPath': 'QmcoobKpoxpacvSNAPCLHGdPt4P27G7U9CPz2rMQpXkCjr/metadata.json', 'dateMinted': '1639907881', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xd0f2bc7a51b179a8090da0ef44b90007f9bc8837'}, 'event': 'Bid', 'date': '1639988119', 'amountInETH': '0.5'}], 'lastSalePriceInETH': '0.5'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2021-12-20 08:15:19 UTC
# FND Link: https://foundation.app/@Okanyan/NEBC/2
# id: 0x2da88c8a45f32f2f84d7c675512ab045b3673cf9
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '81226', 'tokenIPFSPath': 'QmSHB42b4XyGMQ7rKp3bLqDExKgifCBvJaacmLTnCT52Yq/metadata.json', 'dateMinted': '1630840413', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x1d4b9b250b1bd41daa35d94bf9204ec1b0494ee3'}, 'event': 'Bid', 'date': '1633905132', 'amountInETH': '0.7'}], 'lastSalePriceInETH': '0.7'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.7 ETH
# Event Date: 2021-10-10 22:32:12 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/81226
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '94488', 'tokenIPFSPath': 'QmRvhvTbaJeyAz3sDjHnsQbTT8ZpTuGyXoUyCqpQsF45rc/metadata.json', 'dateMinted': '1633347074', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xe35c3d08163da9bd4efa00879a78504d69820b5c'}, 'event': 'Bid', 'date': '1633379663', 'amountInETH': '0.5'}], 'lastSalePriceInETH': '0.5'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2021-10-04 20:34:23 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/94488
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '95403', 'tokenIPFSPath': 'Qmdj7A1kFfGBZGK2TtnGuzwK6JtALVngSHfSv9eEn9MyCb/metadata.json', 'dateMinted': '1633696662', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xb1e415a682ae94f8f5e8729b7441c94d525d7757'}, 'event': 'Bid', 'date': '1633798102', 'amountInETH': '0.5'}, {'actorAccount': {'id': '0xc2d14c396822ba325aa8c8d0f6213828cb69d925'}, 'event': 'Bid', 'date': '1633853507', 'amountInETH': '0.55'}, {'actorAccount': {'id': '0xb1e415a682ae94f8f5e8729b7441c94d525d7757'}, 'event': 'Bid', 'date': '1633879050', 'amountInETH': '0.61'}], 'lastSalePriceInETH': '0.61'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2021-10-09 16:48:22 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/95403
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.55 ETH
# Event Date: 2021-10-10 08:11:47 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/95403
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.61 ETH
# Event Date: 2021-10-10 15:17:30 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/95403
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '105904', 'tokenIPFSPath': 'Qmd2AHA3TH6RpB8XneGYshMRozhVgejPnWsd25paH4TJWt/metadata.json', 'dateMinted': '1636309219', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xc569ddad0ba0f22fce53b0422a0f80acc9f8b1d3'}, 'event': 'Bid', 'date': '1636340625', 'amountInETH': '0.5'}, {'actorAccount': {'id': '0xccd7faa25d2bd8bd6458129e789a1d492100b41f'}, 'event': 'Bid', 'date': '1636426628', 'amountInETH': '0.6'}], 'lastSalePriceInETH': '0.6'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2021-11-08 03:03:45 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/105904
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.6 ETH
# Event Date: 2021-11-09 02:57:08 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/105904
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '128433', 'tokenIPFSPath': 'QmavYWG3DJ4or45frskFVxvmDHojKMZYg96NBa3T7Zvw41/metadata.json', 'dateMinted': '1641648269', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x1ecf823c05f97c390d86deff57c03ade4575c380'}, 'event': 'Bid', 'date': '1641711698', 'amountInETH': '0.5'}], 'lastSalePriceInETH': '0.5'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2022-01-09 07:01:38 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/128433
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '131800', 'tokenIPFSPath': 'Qmed4EtMmgaVk8TEv8ALirTvCtbT3vRpDC2orvWm6LCCKy/metadata.json', 'dateMinted': '1642998071', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x6a8b40fb25a90a09151453aa79d569a7279f1ff6'}, 'event': 'Bid', 'date': '1643000252', 'amountInETH': '0.5'}, {'actorAccount': {'id': '0x1d4b9b250b1bd41daa35d94bf9204ec1b0494ee3'}, 'event': 'Bid', 'date': '1643049432', 'amountInETH': '0.6'}, {'actorAccount': {'id': '0x6a8b40fb25a90a09151453aa79d569a7279f1ff6'}, 'event': 'Bid', 'date': '1643054054', 'amountInETH': '0.66'}, {'actorAccount': {'id': '0x1d4b9b250b1bd41daa35d94bf9204ec1b0494ee3'}, 'event': 'Bid', 'date': '1643066479', 'amountInETH': '0.74'}, {'actorAccount': {'id': '0x6a8b40fb25a90a09151453aa79d569a7279f1ff6'}, 'event': 'Bid', 'date': '1643066588', 'amountInETH': '0.82'}], 'lastSalePriceInETH': '0.82'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2022-01-24 04:57:32 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/131800
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.6 ETH
# Event Date: 2022-01-24 18:37:12 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/131800
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.66 ETH
# Event Date: 2022-01-24 19:54:14 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/131800
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.74 ETH
# Event Date: 2022-01-24 23:21:19 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/131800
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.82 ETH
# Event Date: 2022-01-24 23:23:08 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/131800
# {'nftContract': {'id': '0x727095ccd3c4b5b3188785f3f5171129f6eb5a10', 'name': 'KYP005 ✦✦✦', 'symbol': 'KYP'}, 'tokenId': '1', 'tokenIPFSPath': 'Qmd9egLXhXAzfidZgwYnj9bQutXB38Gkuk58bdcXgxyd2L/metadata.json', 'dateMinted': '1647262948', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x1fb576ce36f72b056b456554622335e9dccd6f3f'}, 'event': 'Bid', 'date': '1647357427', 'amountInETH': '0.268'}, {'actorAccount': {'id': '0x26aeab9bc6630bf8e155770ab314ec5f8169edb5'}, 'event': 'Bid', 'date': '1647357680', 'amountInETH': '0.2969'}, {'actorAccount': {'id': '0xc569ddad0ba0f22fce53b0422a0f80acc9f8b1d3'}, 'event': 'Bid', 'date': '1647359191', 'amountInETH': '0.5'}], 'lastSalePriceInETH': '0.5'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.268 ETH
# Event Date: 2022-03-15 15:17:07 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2969 ETH
# Event Date: 2022-03-15 15:21:20 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2022-03-15 15:46:31 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/1
# {'nftContract': {'id': '0x415e3073a91c66d16245df90b7c56c96c7fa3b52', 'name': 'Morningstar ✦✦✦', 'symbol': 'LUCI'}, 'tokenId': '1', 'tokenIPFSPath': 'QmUv4jVF5dfiNyrj5pdhbqSzwfNJAUMmpBTbzj2QRyMJWo/metadata.json', 'dateMinted': '1648742851', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xc9bca422a142f20707dba2edb455c64ff71854b0'}, 'event': 'Bid', 'date': '1648886016', 'amountInETH': '0.25'}, {'actorAccount': {'id': '0xe5e11deea750f13aab60b780c3a0f62b08b89c9a'}, 'event': 'Bid', 'date': '1648888657', 'amountInETH': '0.275'}, {'actorAccount': {'id': '0x1d4b9b250b1bd41daa35d94bf9204ec1b0494ee3'}, 'event': 'Bid', 'date': '1648931511', 'amountInETH': '0.6'}], 'lastSalePriceInETH': '0.6'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.25 ETH
# Event Date: 2022-04-02 07:53:36 UTC
# FND Link: https://foundation.app/@Okanyan/LUCI/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.275 ETH
# Event Date: 2022-04-02 08:37:37 UTC
# FND Link: https://foundation.app/@Okanyan/LUCI/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.6 ETH
# Event Date: 2022-04-02 20:31:51 UTC
# FND Link: https://foundation.app/@Okanyan/LUCI/1
# {'nftContract': {'id': '0x727095ccd3c4b5b3188785f3f5171129f6eb5a10', 'name': 'KYP005 ✦✦✦', 'symbol': 'KYP'}, 'tokenId': '2', 'tokenIPFSPath': 'QmSeLD5Yha7ubPhfKgWnfhd656fT2Hn1fJaZ8UbcRdYMBd/metadata.json', 'dateMinted': '1655126314', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x938a0af4b86057489bc651dd02c080890d8ed5e5'}, 'event': 'Bid', 'date': '1655650469', 'amountInETH': '0.25'}], 'lastSalePriceInETH': '0.25'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.25 ETH
# Event Date: 2022-06-19 14:54:29 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/2
# {'nftContract': {'id': '0x727095ccd3c4b5b3188785f3f5171129f6eb5a10', 'name': 'KYP005 ✦✦✦', 'symbol': 'KYP'}, 'tokenId': '3', 'tokenIPFSPath': 'QmUKxJYNq1E6btwPcHFg9KasQ6xXV4Ej3gCWdydm2TgMfH/metadata.json', 'dateMinted': '1655826029', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x2ae76a64472e6289ad8d7bdb1682f2f112f6db79'}, 'event': 'Bid', 'date': '1655914339', 'amountInETH': '0.44'}, {'actorAccount': {'id': '0xd74661aadd637d497fabd7f66837739e47066459'}, 'event': 'Bid', 'date': '1655914369', 'amountInETH': '0.53'}, {'actorAccount': {'id': '0x3919dd0d75c370c36c70846d1f2c3c618b42c81b'}, 'event': 'Bid', 'date': '1655914392', 'amountInETH': '0.59'}, {'actorAccount': {'id': '0x017d3e347ebd24b3ae016f8bc2a78369b9a33eaf'}, 'event': 'Bid', 'date': '1655915673', 'amountInETH': '0.649'}, {'actorAccount': {'id': '0x2cd03d3ce4c5ec075f259ccc85d19706a9090dcc'}, 'event': 'Bid', 'date': '1655916354', 'amountInETH': '0.7169'}, {'actorAccount': {'id': '0xb618aacb9dcdc21ca69d310a6fc04674d293a193'}, 'event': 'Bid', 'date': '1655922654', 'amountInETH': '0.7888'}, {'actorAccount': {'id': '0x06e9029d11bbfb137e816805e0a6d84ff57e8637'}, 'event': 'Bid', 'date': '1655994254', 'amountInETH': '0.87'}, {'actorAccount': {'id': '0xb618aacb9dcdc21ca69d310a6fc04674d293a193'}, 'event': 'Bid', 'date': '1655995680', 'amountInETH': '0.96'}], 'lastSalePriceInETH': '0.96'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.44 ETH
# Event Date: 2022-06-22 16:12:19 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.53 ETH
# Event Date: 2022-06-22 16:12:49 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.59 ETH
# Event Date: 2022-06-22 16:13:12 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.649 ETH
# Event Date: 2022-06-22 16:34:33 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.7169 ETH
# Event Date: 2022-06-22 16:45:54 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.7888 ETH
# Event Date: 2022-06-22 18:30:54 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.87 ETH
# Event Date: 2022-06-23 14:24:14 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/3
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.96 ETH
# Event Date: 2022-06-23 14:48:00 UTC
# FND Link: https://foundation.app/@Okanyan/KYP/3
# id: 0x60b6f16f8b52c2966420fb4a7f9d1b7fdb999518
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '81624', 'tokenIPFSPath': 'Qmcita45wzCKkH5Khr744HZaFR7ofA6RH11NvSkZGKNLB9/metadata.json', 'dateMinted': '1630921531', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xb83216ce43714fdac527d809dfcd9dd07d11623a'}, 'event': 'Bid', 'date': '1635304522', 'amountInETH': '0.55'}], 'lastSalePriceInETH': '0.55'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.55 ETH
# Event Date: 2021-10-27 03:15:22 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/81624
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '82957', 'tokenIPFSPath': 'QmQikwZ9pEAWuag4TW71o4pwoFR5K5wuBj6MZCTWGcvHH5/metadata.json', 'dateMinted': '1631249241', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x3b62964e26e57e7da2afdb5e59ba4537270e29b3'}, 'event': 'Bid', 'date': '1631263670', 'amountInETH': '0.5'}], 'lastSalePriceInETH': '0.5'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2021-09-10 08:47:50 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/82957
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '102872', 'tokenIPFSPath': 'QmRutW5cR4Xz1LtnpRMLuoMaNFPTp7e4PrBc29pvjNeRKW/metadata.json', 'dateMinted': '1635164336', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xe76091f84ddf27f9e773ca8bd2090830943f615c'}, 'event': 'Bid', 'date': '1635193759', 'amountInETH': '0.5'}, {'actorAccount': {'id': '0xd0981289f2a7c742773cb417d23f64541028c6e1'}, 'event': 'Bid', 'date': '1635275043', 'amountInETH': '0.55'}], 'lastSalePriceInETH': '0.55'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2021-10-25 20:29:19 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/102872
# ==================================================
# :partying_face: Yay! :partying_face:
# ...
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.35 ETH
# Event Date: 2022-02-13 15:14:02 UTC
# FND Link: https://foundation.app/@Okanyan/BACKHOME/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.385 ETH
# Event Date: 2022-02-14 15:04:54 UTC
# FND Link: https://foundation.app/@Okanyan/BACKHOME/1
# {'nftContract': {'id': '0x3372a685d5ef9f445f234dcc28cf2c7f465945e0', 'name': 'The way back home', 'symbol': 'BACKHOME'}, 'tokenId': '2', 'tokenIPFSPath': 'QmWrn3BPew7TvzSGgf3139uyJsD1fFk5sFgqxuuvZF2rZ7/metadata.json', 'dateMinted': '1646337392', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x8888888888e9997e64793849389a8faf5e8e547c'}, 'event': 'Bid', 'date': '1646356466', 'amountInETH': '0.4201'}, {'actorAccount': {'id': '0xd3e401814d1faa8ca0419ecccbfee93ac7b15b31'}, 'event': 'Bid', 'date': '1646438131', 'amountInETH': '0.4622'}], 'lastSalePriceInETH': '0.4622'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.4201 ETH
# Event Date: 2022-03-04 01:14:26 UTC
# FND Link: https://foundation.app/@Okanyan/BACKHOME/2
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.4622 ETH
# Event Date: 2022-03-04 23:55:31 UTC
# FND Link: https://foundation.app/@Okanyan/BACKHOME/2
# {'nftContract': {'id': '0x3372a685d5ef9f445f234dcc28cf2c7f465945e0', 'name': 'The way back home', 'symbol': 'BACKHOME'}, 'tokenId': '3', 'tokenIPFSPath': 'QmZF4bPscn2v64sJneJUr68BtAUD2RTHDrp8rSMUa2d8dr/metadata.json', 'dateMinted': '1648347922', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x8888888888e9997e64793849389a8faf5e8e547c'}, 'event': 'Bid', 'date': '1648382270', 'amountInETH': '0.5'}], 'lastSalePriceInETH': '0.5'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2022-03-27 11:57:50 UTC
# FND Link: https://foundation.app/@Okanyan/BACKHOME/3
# {'nftContract': {'id': '0x3372a685d5ef9f445f234dcc28cf2c7f465945e0', 'name': 'The way back home', 'symbol': 'BACKHOME'}, 'tokenId': '4', 'tokenIPFSPath': 'QmdbEiYsywqQdN9eY7BfCydZbH3Xiszqjn2bsi4BJENXR3/metadata.json', 'dateMinted': '1650792428', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x8888888888e9997e64793849389a8faf5e8e547c'}, 'event': 'Bid', 'date': '1650797676', 'amountInETH': '0.39'}], 'lastSalePriceInETH': '0.39'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.39 ETH
# Event Date: 2022-04-24 10:54:36 UTC
# FND Link: https://foundation.app/@Okanyan/BACKHOME/4
# {'nftContract': {'id': '0x3372a685d5ef9f445f234dcc28cf2c7f465945e0', 'name': 'The way back home', 'symbol': 'BACKHOME'}, 'tokenId': '5', 'tokenIPFSPath': 'QmSFM5tXLmrHhdTqPpshNpkHZxdvxTAAf4RWgnPAmAK2fj/metadata.json', 'dateMinted': '1653162944', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x0efcd0773330a483e2f456d25d69311dde65e3a7'}, 'event': 'Bid', 'date': '1653356280', 'amountInETH': '0.39'}, {'actorAccount': {'id': '0x2fb5bf565ca66786bf2c2b3f7f47b5e0c650768c'}, 'event': 'Bid', 'date': '1653441866', 'amountInETH': '0.429'}], 'lastSalePriceInETH': '0.429'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.39 ETH
# Event Date: 2022-05-24 01:38:00 UTC
# FND Link: https://foundation.app/@Okanyan/BACKHOME/5
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.429 ETH
# Event Date: 2022-05-25 01:24:26 UTC
# FND Link: https://foundation.app/@Okanyan/BACKHOME/5
# {'nftContract': {'id': '0x3372a685d5ef9f445f234dcc28cf2c7f465945e0', 'name': 'The way back home', 'symbol': 'BACKHOME'}, 'tokenId': '7', 'tokenIPFSPath': 'QmNq4xFPeL7C2Cj6vaiqx22Dx93jMThw1o7S4AKWEV2Lcc/metadata.json', 'dateMinted': '1656244867', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xa5ed4cb9f460e89303ff1bf8b11b20987a4a2f72'}, 'event': 'BuyPriceAccepted', 'date': '1656279160', 'amountInETH': '0.5'}], 'lastSalePriceInETH': '0.5'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5 ETH
# Event Date: 2022-06-26 21:32:40 UTC
# FND Link: https://foundation.app/@Okanyan/BACKHOME/7
# id: 0xa6616f91d6a6d554213ca3f11f87dc525ea82803
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '93020', 'tokenIPFSPath': 'Qme1TpDtEvNh3Kc9f5hsHsLr5qzFBP6MzrbgLpU7Dc4kSw/metadata.json', 'dateMinted': '1633065109', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x08d816526bdc9d077dd685bd9fa49f58a5ab8e48'}, 'event': 'Bid', 'date': '1633620790', 'amountInETH': '0.5337'}], 'lastSalePriceInETH': '0.5337'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.5337 ETH
# Event Date: 2021-10-07 15:33:10 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/93020
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '102135', 'tokenIPFSPath': 'Qme9iFBVU8DDW473p9WdDUPVnkXxWWZXy39KMQFfwvqEpn/metadata.json', 'dateMinted': '1635017878', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xbfb744bf537a17fdcd66e79c0231e6cfeaa428b9'}, 'event': 'Bid', 'date': '1638246007', 'amountInETH': '0.3'}], 'lastSalePriceInETH': '0.3'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.3 ETH
# Event Date: 2021-11-30 04:20:07 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/102135
# {'nftContract': {'id': '0x8dd77d6917b2a667d4e1921c1008beaa6f6caa83', 'name': 'Walpurgis', 'symbol': 'WITCH'}, 'tokenId': '1', 'tokenIPFSPath': 'QmXQsbhCFi7bRKU6FqaH5b8eT3NkTbXB4JpTK4QhedczfR/metadata.json', 'dateMinted': '1642532633', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x5338035c008ea8c4b850052bc8dad6a33dc2206c'}, 'event': 'Bid', 'date': '1642535920', 'amountInETH': '0.3'}], 'lastSalePriceInETH': '0.3'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.3 ETH
# Event Date: 2022-01-18 19:58:40 UTC
# FND Link: https://foundation.app/@Okanyan/WITCH/1
# {'nftContract': {'id': '0x964853402e9f60cbb47f465de95ccfd3e9ed878d', 'name': 'Nekobox Collection', 'symbol': 'NEKO'}, 'tokenId': '1', 'tokenIPFSPath': 'QmSTnsrB9YpuxAGVwNnVgKRrUxiy7idrP5LRxkKpxkPMQK/metadata.json', 'dateMinted': '1644310026', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xbd74c3f96c38478460a0e3c88ac86dd133af72be'}, 'event': 'Bid', 'date': '1644571256', 'amountInETH': '0.15'}], 'lastSalePriceInETH': '0.15'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2022-02-11 09:20:56 UTC
# FND Link: https://foundation.app/@Okanyan/NEKO/1
# {'nftContract': {'id': '0x964853402e9f60cbb47f465de95ccfd3e9ed878d', 'name': 'Nekobox Collection', 'symbol': 'NEKO'}, 'tokenId': '3', 'tokenIPFSPath': 'QmVMtx5ixkiQiVDBRdGteVvQiDLq7JqT6XUBNXC3sLcFaE/metadata.json', 'dateMinted': '1647088884', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xd63c2582b071f41090e89d975f738e87e7b8da50'}, 'event': 'Bid', 'date': '1647173597', 'amountInETH': '0.2'}], 'lastSalePriceInETH': '0.2'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2022-03-13 12:13:17 UTC
# FND Link: https://foundation.app/@Okanyan/NEKO/3
# {'nftContract': {'id': '0x8dd77d6917b2a667d4e1921c1008beaa6f6caa83', 'name': 'Walpurgis', 'symbol': 'WITCH'}, 'tokenId': '2', 'tokenIPFSPath': 'QmTbS8LChy2QMbLMWx41i7FMCVJoaLmioKj4HMUNMfcqBg/metadata.json', 'dateMinted': '1647346444', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xe9b4cc09a97d6ad079ea20c0701e11c796321cb0'}, 'event': 'Bid', 'date': '1647806258', 'amountInETH': '0.21'}], 'lastSalePriceInETH': '0.21'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.21 ETH
# Event Date: 2022-03-20 19:57:38 UTC
# FND Link: https://foundation.app/@Okanyan/WITCH/2
# {'nftContract': {'id': '0x4cd2fa516dbafb7f313cd5a86b6915e2093b2250', 'name': 'PHENOMENAL WAIFU', 'symbol': 'WAIFU'}, 'tokenId': '2', 'tokenIPFSPath': 'QmRUyr93wV2Su9Pw7cjLW2LgeVgapfNeWTwikgaPpBdX1Q/metadata.json', 'dateMinted': '1654544232', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xadb14a1728a603691f948e3480c98461fb06e738'}, 'event': 'Bid', 'date': '1655178007', 'amountInETH': '0.15'}], 'lastSalePriceInETH': '0.15'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2022-06-14 03:40:07 UTC
# FND Link: https://foundation.app/@Okanyan/WAIFU/2
# {'nftContract': {'id': '0x964853402e9f60cbb47f465de95ccfd3e9ed878d', 'name': 'Nekobox Collection', 'symbol': 'NEKO'}, 'tokenId': '5', 'tokenIPFSPath': 'QmYs5YzFasXrRvuFNV5mYwuj5BKGgB1wRk3YBrVwGu9HvH/metadata.json', 'dateMinted': '1655227334', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x2eddce3e4fc85d6a4bd11ae96a489937d9df8908'}, 'event': 'Bid', 'date': '1655815908', 'amountInETH': '0.1069'}], 'lastSalePriceInETH': '0.1069'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1069 ETH
# Event Date: 2022-06-21 12:51:48 UTC
# FND Link: https://foundation.app/@Okanyan/NEKO/5
# id: 0xae6523e811edc6d16b806875fbf2082e01fb3117
# {'nftContract': {'id': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405', 'name': 'FND NFT', 'symbol': 'FNDNFT'}, 'tokenId': '129785', 'tokenIPFSPath': 'QmewbBxEk1RdCUWCM22igF7f5QtKwjUHnn1ZtQwQfmHkeU/metadata.json', 'dateMinted': '1642308691', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xd0fe971732e547059ea6009c79a2d6155bdb41a4'}, 'event': 'Bid', 'date': '1642564805', 'amountInETH': '0.369'}], 'lastSalePriceInETH': '0.369'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.369 ETH
# Event Date: 2022-01-19 04:00:05 UTC
# FND Link: https://foundation.app/@Okanyan/FNDNFT/129785
# id: 0xf46e179d808ebdfaed29cd511326aee00049bcfa
# {'nftContract': {'id': '0xd245eb541ae80ed09e08dc33054b92148dbf071a', 'name': 'Kemonomimi', 'symbol': 'OKAMI'}, 'tokenId': '1', 'tokenIPFSPath': 'QmScFpHHwDVcPZHt2kPpzSjF2ARggUkmsSiK5mvAM3x1un/metadata.json', 'dateMinted': '1644732835', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xbd74c3f96c38478460a0e3c88ac86dd133af72be'}, 'event': 'Bid', 'date': '1644797098', 'amountInETH': '0.2'}], 'lastSalePriceInETH': '0.2'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2022-02-14 00:04:58 UTC
# FND Link: https://foundation.app/@Okanyan/OKAMI/1
# {'nftContract': {'id': '0xd245eb541ae80ed09e08dc33054b92148dbf071a', 'name': 'Kemonomimi', 'symbol': 'OKAMI'}, 'tokenId': '2', 'tokenIPFSPath': 'QmQxFZMkUQ4jY1gqDd3FpEWjYZKwWk46QH6E7Wq3Jrsjcn/metadata.json', 'dateMinted': '1644943071', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x8efcdb88d8b6beb1f240f3f15e1b56d9c1c7cffa'}, 'event': 'Bid', 'date': '1645204306', 'amountInETH': '0.2'}], 'lastSalePriceInETH': '0.2'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2022-02-18 17:11:46 UTC
# FND Link: https://foundation.app/@Okanyan/OKAMI/2
# {'nftContract': {'id': '0xd245eb541ae80ed09e08dc33054b92148dbf071a', 'name': 'Kemonomimi', 'symbol': 'OKAMI'}, 'tokenId': '3', 'tokenIPFSPath': 'QmZ73DWKg8vRvwSTW1g89twPEZ5y7WAWtrJuNc78VhUq8x/metadata.json', 'dateMinted': '1645517450', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x08109a9be5dd5387e9b3982c73da41cb1df1ce4a'}, 'event': 'Bid', 'date': '1645980203', 'amountInETH': '0.15'}], 'lastSalePriceInETH': '0.15'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.15 ETH
# Event Date: 2022-02-27 16:43:23 UTC
# FND Link: https://foundation.app/@Okanyan/OKAMI/3
# {'nftContract': {'id': '0x77aed5d1fa06c6f45ccc655d96c575a880b6f789', 'name': 'Yōkai', 'symbol': 'ESPRIT'}, 'tokenId': '1', 'tokenIPFSPath': 'QmUTv64FMM33n47TLDNRkiurN6WfD9qN7DCnCZymw8DUP3/metadata.json', 'dateMinted': '1651718644', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0xfb36e3caf9351350b2b8fdf65cec3b7fcfa13187'}, 'event': 'Bid', 'date': '1651739955', 'amountInETH': '0.2'}, {'actorAccount': {'id': '0x08109a9be5dd5387e9b3982c73da41cb1df1ce4a'}, 'event': 'Bid', 'date': '1651740631', 'amountInETH': '0.22'}, {'actorAccount': {'id': '0xfb36e3caf9351350b2b8fdf65cec3b7fcfa13187'}, 'event': 'Bid', 'date': '1651746392', 'amountInETH': '0.242'}], 'lastSalePriceInETH': '0.242'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.2 ETH
# Event Date: 2022-05-05 08:39:15 UTC
# FND Link: https://foundation.app/@Okanyan/ESPRIT/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.22 ETH
# Event Date: 2022-05-05 08:50:31 UTC
# FND Link: https://foundation.app/@Okanyan/ESPRIT/1
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.242 ETH
# Event Date: 2022-05-05 10:26:32 UTC
# FND Link: https://foundation.app/@Okanyan/ESPRIT/1
# {'nftContract': {'id': '0x77aed5d1fa06c6f45ccc655d96c575a880b6f789', 'name': 'Yōkai', 'symbol': 'ESPRIT'}, 'tokenId': '2', 'tokenIPFSPath': 'QmSyuuCTgAAp78U2vAWcv9g2WKuNSRTpWjz7BRMXmpnnKr/metadata.json', 'dateMinted': '1655440520', 'isFirstSale': False, 'nftHistory': [{'actorAccount': {'id': '0x56bc755e6b29cc7887e50d77f370f9fd416b7780'}, 'event': 'Bid', 'date': '1655441601', 'amountInETH': '0.1'}, {'actorAccount': {'id': '0x8fb9afdcc074599d86327b731f47ffa5375823a9'}, 'event': 'Bid', 'date': '1655469699', 'amountInETH': '0.11'}, {'actorAccount': {'id': '0xb35248feeb246b850fac690a1beaf5130dc71894'}, 'event': 'Bid', 'date': '1655488026', 'amountInETH': '0.125'}, {'actorAccount': {'id': '0x8fb9afdcc074599d86327b731f47ffa5375823a9'}, 'event': 'Bid', 'date': '1655525408', 'amountInETH': '0.1375'}], 'lastSalePriceInETH': '0.1375'}
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1 ETH
# Event Date: 2022-06-17 04:53:21 UTC
# FND Link: https://foundation.app/@Okanyan/ESPRIT/2
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.11 ETH
# Event Date: 2022-06-17 12:41:39 UTC
# FND Link: https://foundation.app/@Okanyan/ESPRIT/2
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.125 ETH
# Event Date: 2022-06-17 17:47:06 UTC
# FND Link: https://foundation.app/@Okanyan/ESPRIT/2
# ==================================================
# :partying_face: Yay! :partying_face:
# Oka has brought home the dough for 0.1375 ETH
# Event Date: 2022-06-18 04:10:08 UTC
# FND Link: https://foundation.app/@Okanyan/ESPRIT/2

# %%
def constructLink(username,collectName, tokenId):
    if (collectName == "FND NFT"):
        collectName = "foundation"
    return f"https://foundation.app/{username}/{collectName}/{tokenId}"

# %%
def getUsernameByWallet(addr):
    #TODO: access local json
    return "@Okanyan"

# %%
def getNameByWallet(addr):
    return "Oka"

# %%
def eventStrings(evt,name,price = 0):
    if (evt == "Bid"):
        return [
            ":moneybag: BID RECEIVED :moneybag:",
            f"{name}'s below NFT has received a bid for {price} ETH"
        ]
    elif (evt == "BuyPriceAccepted"):
        return [
            ":moneybag: BUY NOW PRICE ACCEPTED :moneybag:",
            f"{name}'s below NFT's Buy Now Price was accepted for {price} ETH"
        ] 
    elif (evt == "Minted"):
        return [
            "🔨 MINTING 🔨",
            f"{name} has minted the below NFT"
        ]
    elif (evt == "Listed"):
        return [
            "🌟 LISTING 🌟",
            f"{name} has listed the below NFT for {price} ETH"
        ]
    elif (evt == "PriceChanged"):
        return [
            "📈 PRICE CHANGE 📉 ",
            f"{name} has changed the below NFT's price to {price} ETH"
        ]
    elif (evt == "Unlisted"):
        return [
            "❌ DELISTING ❌"
            f"{name} has delisted the below NFT"
        ]
    elif (evt == "BuyPriceSet"):
        return [
            "📈 BUY NOW PRICE SET 📉",
            f"{name} has set the below NFT's Buy Now price to {price} ETH"
        ]
    elif (evt == "SellAlr"):
        return [
            ":partying_face: Yay! :partying_face:",
            f"{name} has brought home the dough for {price} ETH"
        ]
#         return "🥈 LISTING ON SECONDARY 🥈",0x53...303d has listed HxxG's NFT below on secondary market for 10 ETH  
    return ""

# %%
def messageCreator(addr, nftObj):
    collectName = nftObj['nftContract']['symbol']
    tokenId = nftObj['tokenId']
    username = getUsernameByWallet(addr)
    name = getNameByWallet(addr)
    link = constructLink(username,collectName,tokenId)
    
#     print(f"art link: {link}")
    for hist in nftObj['nftHistory']:
        print("=" * 50)
        event = hist['event']
        if (nftObj['lastSalePriceInETH'] != None):
            event = "SellAlr"
        eventStrs = eventStrings(event, name, hist['amountInETH'] if 'amountInETH' in hist else 0)
        print(eventStrs[0])
        print(eventStrs[1])
        print(f"Event Date: {datetime.utcfromtimestamp(int(hist['date'])).strftime('%Y-%m-%d %H:%M:%S')} UTC")
        print(f"FND Link: {link}")
