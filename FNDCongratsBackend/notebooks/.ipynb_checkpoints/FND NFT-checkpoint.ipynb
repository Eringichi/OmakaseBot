# %%
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait as wait
from bs4 import BeautifulSoup
import re, requests, clipboard
from subprocess import check_call
import pyperclip
import klembord
# assets = pd.DataFrame(requests.get("https://api.opensea.io/api/v1/assets?order_direction=desc&offset=0&limit=20").json()['assets'])
# assets.head().T

# %%
# get a user's metamask from fnd 
options = Options()
# options.headless = True
options.add_argument('--headless')
driver = webdriver.Chrome('/home/jl/chromedriver', options=options)
# Out:
# /tmp/ipykernel_288570/790193323.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/home/jl/chromedriver', options=options)

# %%
# On Mac use:
def copy2clip(txt):
    cmd='echo '+txt.strip()+'|pbcopy'
    return check_call(cmd, shell=True)

# %%
klembord.init()

# %%
# url = 'https://foundation.app/@tueart'
url2 = 'https://foundation.app/@rofortyseven'
copyMetamaskBtnClass = "st--c-PJLV st--c-dhzjXW st--c-PJLV-ikJqfPx-css".replace(" ",".")
driver.set_window_size(1920, 1080)
driver.get(url2)
# copyBtn = wait(driver, 15).until(EC.element_to_be_clickable((By.CLASS_NAME, copyMetamaskBtnClass)))
copyBtn = driver.find_element(By.CLASS_NAME, copyMetamaskBtnClass)
copyBtn.click()

addr = clipboard.paste() #klembord.get_text()#pyperclip.paste()#

# %%
print(addr)
# Out:
# .add_argument('--headless')

# %%
createContainerClass = "st--c-PJLV st--c-bQzyIt st--c-cpoXkf st--c-dTHMXF".replace(" ",".")
createContainer = driver.find_element(By.CLASS_NAME, createContainerClass)
print(createContainer)
children = createContainer.find_elements(By.XPATH, "*")
# print(children)
for child in children:
    print(child.get_attribute('innerHTML'))
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="72e89f1715d5974f7c1d83680ae62776", element="40aa46a0-a81c-4a39-8464-8886565ee583")>
# ...

# %%
# Get username
usernameClass = "st--c-PJLV st--c-PJLV-disIKw-size-2 st--c-PJLV-iqCzBn-weight-semibold st--c-PJLV-cjUlPD-color-dim st--c-PJLV-umGZz-size-3 st--c-PJLV-icXRXMr-css".replace(" ",".")
el = driver.find_element(By.CLASS_NAME, usernameClass)
# print(dir(el))
print(el.get_attribute('innerHTML'))
# Out:
# @rofortyseven

# %%
nameClass = "st--c-PJLV st--c-kxmHLk st--c-PJLV-boLyXY-size-3 st--c-PJLV-jCZVon-size-4 st--c-kxmHLk-dIdTVS-leading-tight st--c-PJLV-ifOmecJ-css".replace(" ",".")
el = driver.find_element(By.CLASS_NAME, nameClass)
# print(dir(el))
print(el.get_attribute('innerHTML'))
# Out:
# ろ47

# %%
collectionUrl = f"{url2}?tab=collections"
driver.get(collectionUrl)
print(driver.current_url)
collectionClass="st--c-PJLV st--c-bQzyIt st--c-cpoXkf st--c-dTHMXF".replace(" ",".")
collectionsContainer = driver.find_element(By.CLASS_NAME, collectionClass)
children = collectionsContainer.find_elements(By.XPATH, "*")
# print(children)
for child in children:
    print(child.get_attribute('innerHTML'))
# Out:
# https://foundation.app/@rofortyseven?tab=collections
# ...
